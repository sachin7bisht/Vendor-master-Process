# %%
import os
import sys 

import sys
import os

# Get the absolute path to the project root (one level up from 'experiment')
project_root = os.path.abspath(os.path.join(os.getcwd(), '..'))

# Add it to sys.path if it's not already there
if project_root not in sys.path:
    sys.path.append(project_root)

# Now you can import from backend

from backend.src.document_ingestion.data_ingestion import ChatIngestor
from backend.src.document_chat.retrieval import ConversationalRAG
from backend.utils.model_loader import ModelLoader
from dotenv import load_dotenv
from pathlib import Path
from langchain_core.messages import AIMessage, HumanMessage

load_dotenv()



def test_doc_ingestion_and_rag():
    try:
        test_file=['/Users/sachinbeast/Desktop/main/system/VMP_final/data/final_data.csv']
        uploaded_file=[]

        for filepath in test_file:
            if Path(filepath).is_file():
                f=open(filepath,'rb')
                uploaded_file.append(f)
                print('done')
            else:
                print('--------------')
                print(f"File not found: {filepath}")
        
        
        if not uploaded_file:
            print("No valid files found for ingestion")
            sys.exit(1)

        print('File Uplaoded successfully')

        ci=ChatIngestor(temp_base='data',faiss_base='faiss_index',use_session_dirs=True)

        ret=ci.built_retriver(uploaded_files=uploaded_file,
        chunk_size=100,
        chunk_overlap=20,
        k=5,
        search_type='mmr',
        fetch_k=20,
        lambda_mult=0.5
        )


        for f in uploaded_file:
            try:
                f.close()
            except Exception as e:
                print(f"Failed to close file: {f}")
        
        session_id=ci.session_id

        index_dir=os.path.join('faiss_index',session_id)

        rag=ConversationalRAG(session_id=session_id,retriever=ret)

        # rag.load_retriever_from_faiss(
        #     index_path=index_dir, 
        #     k=5, 
        #     index_name=os.getenv("FAISS_INDEX_NAME", "index"),
        #     search_type="mmr",
        #     fetch_k=20,
        #     lambda_mult=0.5
        # )

        chat_history=[]

        print('type exit to quit')

        while True:
            try:
                user_input=input('You: ').strip()
                if user_input.lower()=='exit':
                    break
                
            except (EOFError, KeyboardInterrupt):
                print("Bye!")
                break

            if not user_input:
                continue
            if user_input.lower() in {"exit", "quit", "q", ":q"}:
                print("Goodbye!")
                break
            
            answer=rag.invoke(user_input,chat_history=chat_history)
            print('Assistant: ',answer)

            chat_history.append(HumanMessage(content=user_input))
            chat_history.append(AIMessage(content=answer))
            
    except Exception as e:
        print(f"Error: {e}")
        sys.exit(1)

if __name__=='__main__':
    test_doc_ingestion_and_rag()
# Out:
# {"timestamp": "2026-01-06T10:50:57.377511Z", "level": "info", "event": "Running in LOCAL mode: .env loaded"}
# {"timestamp": "2026-01-06T10:50:57.377780Z", "level": "info", "event": "Loaded OPENAI_API_KEY from individual env var"}
# {"keys": {"OPENAI_API_KEY": "sk-pro..."}, "timestamp": "2026-01-06T10:50:57.377982Z", "level": "info", "event": "API keys loaded"}
# {"config_keys": ["embedding_model", "retriever", "llm"], "timestamp": "2026-01-06T10:50:57.379153Z", "level": "info", "event": "YAML config loaded"}
# {"session_id": "session_20260106_162057_25d93da6", "temp_dir": "data/session_20260106_162057_25d93da6", "faiss_dir": "faiss_index/session_20260106_162057_25d93da6", "sessionized": true, "timestamp": "2026-01-06T10:50:57.379659Z", "level": "info", "event": "ChatIngestor initialized"}
# {"uploaded": "/Users/sachinbeast/Desktop/main/system/VMP_final/data/final_data.csv", "saved_as": "data/session_20260106_162057_25d93da6/final_data_66850c.csv", "timestamp": "2026-01-06T10:50:57.380238Z", "level": "info", "event": "File saved for ingestion"}
# {"count": 1002, "timestamp": "2026-01-06T10:50:57.389802Z", "level": "info", "event": "Documents loaded"}
# {"chunks": 15979, "chunk_size": 100, "overlap": 20, "timestamp": "2026-01-06T10:50:57.443026Z", "level": "info", "event": "Documents split"}
# {"model": "text-embedding-3-small", "timestamp": "2026-01-06T10:50:57.443583Z", "level": "info", "event": "Loading embedding model"}
# done
# File Uplaoded successfully
# in ChatIngestor
# in ApiKeyManager
# /Users/sachinbeast/Desktop/main/system/VMP_final/backend/config/config.yaml
# ChatIngestor initialized. log info
# in built_retriver
# path after saving files---- [PosixPath('data/session_20260106_162057_25d93da6/final_data_66850c.csv')]
# loaded---- [Document(metadata={'source': 'data/session_20260106_162057_25d93da6/final_data_66850c.csv', 'row': 0}, page_content="Unnamed: 0: 0.0\nuser_id: 3472.0\nname: Aaron Roberts\nemail: jchavez@gmail.com\ncompany: Brown Inc\nrole: Procurement Manager\nverified: True\nitem_id: C103\nitem_name: Jet Fuel Pump\ncategory: Engine Parts\ndescription: Fuel pump for jet engines\nprice: 8750.25\nsupplier: JetSupply Ltd\nstock: 39.0\ninvoice_id: INV-1638\nvendor_id: V7755\ninvoice_date: 2025-08-08\ndue_date: 2025-09-07\namount: 341259.75\nstatus: Overdue\nrelated_item_id: C103\nfrom: jchavez@gmail.com\nto: support@aerosupply.com\nsubject: Invoice status inquiry INV-1638\nbody: Hello, could you confirm the status of invoice INV-1638 for Jet Fuel Pump?\nemail_type: Invoice Query\ngenerated_reply: Dear Aaron Roberts, the payment status for invoice INV-1638 is Overdue.\nresponse_date: 2025-08-09\nsummary: Aaron Roberts requested status of INV-1638 for Jet Fuel Pump; response sent confirming Overdue.\nprevious_interactions: [{'uuid': '9e5e47fc-545e-411d-8133-ddb59f71d43b', 'context': 'User requested catalog details for Jet Fuel Pump (C103)'}]\nphone: 9569733980.0\naddress: 862, Main Street, City3\ntimestamp: \nreply_text: \naction_taken: "), Document(metadata={'source': 'data/session_20260106_162057_25d93da6/final_data_66850c.csv', 'row': 1}, page_content="Unnamed: 0: 1.0\nuser_id: 2375.0\nname: Peter Reed\nemail: sotochristopher@hotmail.com\ncompany: Garcia, Houston and Best\nrole: Supply Chain Lead\nverified: False\nitem_id: C103\nitem_name: Jet Fuel Pump\ncategory: Engine Parts\ndescription: Fuel pump for jet engines\nprice: 8750.25\nsupplier: JetSupply Ltd\nstock: 4.0\ninvoice_id: INV-4340\nvendor_id: V8858\ninvoice_date: 2025-08-09\ndue_date: 2025-09-08\namount: 2222.0\nstatus: Pending\nrelated_item_id: C103\nfrom: sotochristopher@hotmail.com\nto: support@aerosupply.com\nsubject: Invoice status inquiry INV-4340\nbody: Hello, could you confirm the status of invoice INV-4340 for Jet Fuel Pump?\nemail_type: Invoice Query\ngenerated_reply: Dear Peter Reed, the payment status for invoice INV-4340 is Pending.\nresponse_date: 2025-08-10\nsummary: Peter Reed requested status of INV-4340 for Jet Fuel Pump; response sent confirming Pending.\nprevious_interactions: [{'uuid': '07ea0d56-443f-4be2-8d2c-a045ecf7fe7f', 'context': 'User requested catalog details for Jet Fuel Pump (C103)'}]\nphone: 7724881106.0\naddress: 450, Main Street, City13\ntimestamp: \nreply_text: \naction_taken: "), Document(metadata={'source': 'data/session_20260106_162057_25d93da6/final_data_66850c.csv', 'row': 2}, page_content="Unnamed: 0: 2.0\nuser_id: 7671.0\nname: Amanda Torres\nemail: evelynstewart@rhodes-bradley.org\ncompany: Brooks, Williams and Terrell\nrole: Supply Chain Lead\nverified: True\nitem_id: C105\nitem_name: Flight Control Computer\ncategory: Electronics\ndescription: Onboard flight control system computer\nprice: 15200.99\nsupplier: ControlSys Inc\nstock: 2.0\ninvoice_id: INV-9879\nvendor_id: V8296\ninvoice_date: 2025-08-06\ndue_date: 2025-09-05\namount: 30401.98\nstatus: Paid\nrelated_item_id: C105\nfrom: evelynstewart@rhodes-bradley.org\nto: support@aerosupply.com\nsubject: Invoice status inquiry INV-9879\nbody: Hello, could you confirm the status of invoice INV-9879 for Flight Control Computer?\nemail_type: Invoice Query\ngenerated_reply: Dear Amanda Torres, the payment status for invoice INV-9879 is Paid.\nresponse_date: 2025-08-07\nsummary: Amanda Torres requested status of INV-9879 for Flight Control Computer; response sent confirming Paid.\nprevious_interactions: [{'uuid': '380c7c3c-2ba2-4e90-b392-7a2f9a667bde', 'context': 'User requested catalog details for Flight Control Computer (C105)'}]\nphone: 9383051470.0\naddress: 421, Main Street, City7\ntimestamp: \nreply_text: \naction_taken: "), Document(metadata={'source': 'data/session_20260106_162057_25d93da6/final_data_66850c.csv', 'row': 3}, page_content="Unnamed: 0: 3.0\nuser_id: 7614.0\nname: St ...
# splitting-----
# splitting-----
# splitting done-----
# index_dir for faiss faiss_index/session_20260106_162057_25d93da6
# in load_embeddings
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# Loading faiss.
# Successfully loaded faiss.
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# {"added": 1, "index": "faiss_index/session_20260106_162057_25d93da6", "timestamp": "2026-01-06T10:52:02.256192Z", "level": "info", "event": "FAISS index updated"}
# {"k": 5, "fetch_k": 20, "lambda_mult": 0.5, "timestamp": "2026-01-06T10:52:02.256568Z", "level": "info", "event": "Using MMR search 11"}
# {"timestamp": "2026-01-06T10:52:02.259738Z", "level": "info", "event": "Running in LOCAL mode: .env loaded"}
# {"timestamp": "2026-01-06T10:52:02.259976Z", "level": "info", "event": "Loaded OPENAI_API_KEY from individual env var"}
# {"keys": {"OPENAI_API_KEY": "sk-pro..."}, "timestamp": "2026-01-06T10:52:02.260165Z", "level": "info", "event": "API keys loaded"}
# {"config_keys": ["embedding_model", "retriever", "llm"], "timestamp": "2026-01-06T10:52:02.262747Z", "level": "info", "event": "YAML config loaded"}
# {"provider": "openai", "model": "gpt-4o", "timestamp": "2026-01-06T10:52:02.262955Z", "level": "info", "event": "Loading LLM"}
# {"session_id": "session_20260106_162057_25d93da6", "timestamp": "2026-01-06T10:52:02.273317Z", "level": "info", "event": "LLM loaded successfully"}
# {"session_id": "session_20260106_162057_25d93da6", "timestamp": "2026-01-06T10:52:02.273740Z", "level": "info", "event": "LCEL graph built successfully"}
# {"session_id": "session_20260106_162057_25d93da6", "timestamp": "2026-01-06T10:52:02.274079Z", "level": "info", "event": "ConversationalRAG initialized"}
# in ApiKeyManager
# /Users/sachinbeast/Desktop/main/system/VMP_final/backend/config/config.yaml
# type exit to quit
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# {"session_id": "session_20260106_162057_25d93da6", "user_input": "details of peter reeds", "answer_preview": "Peter Reed is a Procurement Manager at Reed Ltd. His email is sotochristopher@hotmail.com, and he requested the status of invoice INV-4340 for a Jet F", "timestamp": "2026-01-06T10:52:47.195032Z", "level": "info", "event": "Chain invoked successfully"}
# Assistant:  Peter Reed is a Procurement Manager at Reed Ltd. His email is sotochristopher@hotmail.com, and he requested the status of invoice INV-4340 for a Jet Fuel Pump. The response sent to him confirmed that the payment status for this invoice is pending.
# Goodbye!
